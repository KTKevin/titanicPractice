# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.linear_model import LogisticRegression
train = pd.read_csv('train.csv', index_col = 0)
train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
cleaned_file = train.dropna(axis =0, how='any')
cleaned_file
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
# 22                  1       2
# 24                  1       1
# 28                  0       1
# 53                  1       1
# 55                  0       1
# 63                  0       1
# 67                  1       2
# 76                  0       3
# 89                  1       1
# 93                  0       1
# 97                  0       1
# 98                  1       1
# 103                 0       1
# 111                 0       1
# 119                 0       1
# 124                 1       2
# 125                 0       1
# 137                 1       1
# 138                 0       1
# 140                 0       1
# 149                 0       2
# 152                 1       1
# 171                 0       1
# 175                 0       1
# ...

# %%
y = cleaned_file["Survived"]
y = np.array(y)
x1 = cleaned_file["Age"]
x
x2 = cleaned_file["Fare"]
x1 = np.array(x1)
x2 = np.array(x2)
X = np.array([x1,x2])
X = X.transpose()
#take 130 examples of X and y
# put them into variables xtrain, y train
# take remaining examples; 
# put them into variables called xvalidation, yvalidation,
# call fit on the train variables LogReg.fit, call transform on validation LogReg.transform() (only use transform on x).

# %%
LogReg = LogisticRegression()

LogReg.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-5e389ef3366b> in <module>()
# ----> 1 len(x[1])
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    2475         try:
#    2476             return self._engine.get_value(s, k,
# -> 2477                                           tz=getattr(series.dtype, 'tz', None))
#    2478         except KeyError as e1:
#    2479             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# ...
